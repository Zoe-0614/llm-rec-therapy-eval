# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample data extracted from user-provided image
data = {
    "Q1": [1, 3, 7],
    "Q2": [3, 2, 6],
    "Q3": [2, 3, 6],
    "Q4": [1, 2, 8],
    "Q5": [2, 6, 3],
    "Q6": [2, 3, 6],
    "Q7": [0, 5, 6],
    "Q8": [2, 3, 6],
    "Q9": [2, 7, 2],
    "Q10": [3, 0, 8],
    "Q11": [1, 2, 8],
    "Q12": [1, 5, 5],
    "Q13": [2, 3, 6],
    "Q14": [0, 6, 5],
    "Q15": [2, 4, 5],
    "Q16": [3, 3, 5],
    "Q17": [2, 3, 6],
    "Q18": [3, 2, 6],
    "Q19": [4, 2, 5],
    "Q20": [2, 4, 5],
    "Q21": [3, 3, 5],
    "Q22": [3, 1, 7],
    "Q23": [2, 3, 6],
    "Q24": [5, 3, 3],
    "Q25": [4, 2, 5],
    "Q26": [1, 2, 8],
    "Q27": [2, 1, 8],
    "Q28": [3, 5, 3],
    "Q29": [1, 6, 4],
    "Q30": [2, 5, 4],
    "Q31": [4, 2, 5],
    "Q32": [3, 5, 3],
    "Q33": [1, 0, 10],
    "Q34": [3, 1, 7],
    "Q35": [4, 2, 5],
    "Q36": [5, 1, 5],
    "Q37": [3, 1, 7],
    "Q38": [1, 7, 3],
    "Q39": [5, 1, 5],
    "Q40": [2, 3, 6],
    "Q41": [2, 3, 6],
    "Q42": [1, 5, 5],
    "Q43": [2, 3, 6],
    "Q44": [3, 3, 5],
    "Q45": [1, 2, 8],
    "Q46": [5, 2, 4],
    "Q47": [5, 1, 5],
    "Q48": [3, 3, 5]
}

# Creating DataFrame
df = pd.DataFrame(data, index=["Model 1", "Model 2", "Model 3"])

# Transposing for easier plotting
df_transposed = df.T

# Updating the plot
fig, ax = plt.subplots(figsize=(15, 5))
df_transposed.plot(ax=ax, color=['blue', 'green', 'red'])  # Changed colors for clarity
ax.set_xlabel("Question Number")
ax.set_ylabel("Votes")
ax.set_title("Votes per Model Across Different Questions")
ax.legend(title="Model")
plt.xticks(rotation=90)
plt.grid(True)

plt.show()

# %%
# Re-attempting the creation of a stacked bar chart using a more robust method
fig, ax = plt.subplots(figsize=(15, 10))
df_transposed.plot(kind='bar', stacked=True, color=['blue', 'green', 'red'], ax=ax)
ax.set_xlabel("Question Number")
ax.set_ylabel("Votes")
ax.set_title("Votes per Model Across Different Questions")
plt.xticks(rotation=90)
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend(title="Model", loc="upper right")

plt.show()
